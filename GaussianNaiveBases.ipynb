# %%
from pandas import read_csv
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier   #on peut l'appliquer sur plusieurs colonnes
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB


# 1 - Définition du Dataset
names = ["sex", "age", "contract Name", "children", "weight"]
dataset = read_csv("C:/Users/Achraf Said/Desktop/dataset/contracts.csv", sep=";", names=names)
print (dataset)
encodeur = LabelEncoder()
#print('===============================',dataset['contract Name'])
dataset['contract Name']= encodeur.fit_transform(dataset['contract Name'])
print (dataset)

# 2 - Entrainement du modèle
array = dataset.values
X = array[:,0:4]
#print('X ========', X)
y = array[:,4]
#y = array[:,3:5]
#print('y ===========', y)
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.25, random_state=1)
#print ('x_train =====================',X_train)
#print ('y_train =====================',Y_train)

model = GaussianNB()
#model = DecisionTreeClassifier()
model.fit(X_train, Y_train)

# 4 - Prédiction simple
prediction = model.predict([[1, 33, 1,1]])
ligne = [1, 33, 1,1]
#prediction = model.predict([[2, 47, 2]])
print("Predicted Value: %s" % prediction)
#print ('model.classes = ', model.classes_)

predictions = model.predict_proba([[1, 33, 1,1]])
#print(predictions)
for weight, accuracy in zip(model.classes_, predictions[0]):
    if weight == 79:
        print('La probabilité d"apparence de ', weight,' dans cette ligne ', ligne, ' est ', accuracy*100, '% .')
    
    #print(weight, accuracy)
# Out:
#     sex  age contract Name  children  weight
# 0     1   33       Pacific         1      79
# 1     2   21       Pacific         1      75
# 2     1   37       Pacific         1      99
# 3     1   48       Pacific         1      64
# 4     2   31       Pacific         1      98
# ..  ...  ...           ...       ...     ...
# 85    2   25       Venture         3      71
# 86    1   30       Venture         3      80
# 87    2   37       Venture         3      62
# 88    1   33       Venture         3      90
# 89    2   47       Venture         3      83
#
# [90 rows x 5 columns]
#     sex  age  contract Name  children  weight
# 0     1   33              1         1      79
# 1     2   21              1         1      75
# 2     1   37              1         1      99
# 3     1   48              1         1      64
# 4     2   31              1         1      98
# ..  ...  ...            ...       ...     ...
# 85    2   25              2         3      71
# ...
